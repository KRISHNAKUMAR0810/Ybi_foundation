# %% [markdown]
# Title of the project : Mileage prediction using regression analysis

# %% [markdown]
# Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Import data

# %%
Mileage= pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/MPG.csv')

# %%
Mileage
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# Data preprocessing

# %%
Mileage.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
Mileage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
Mileage.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       93
# weight          351
# acceleration     95
# model_year       13
# origin            3
# name            305
# dtype: int64

# %%
features = Mileage[['mpg','cylinders','displacement','horsepower','weight','acceleration','model_year']]
features
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year
# 0            70
# 1            70
# 2            70
# 3            70
# 4            70
# ..          ...
# ...

# %%
features.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %% [markdown]
# Checking missing values

# %%
a = Mileage.isna().sum()
a
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
Mileage.dropna()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# Data visualization

# %%
sns.pairplot(Mileage, x_vars=['cylinders','displacement','horsepower','mpg'], y_vars=['mpg']);

# %%
sns.regplot(x='displacement',y='mpg',data=Mileage)
# Out:
# <Axes: xlabel='displacement', ylabel='mpg'>

# %% [markdown]
# Define Target Variable (y) and Feature Variables (X)

# %%
y = Mileage['mpg']
y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
X = Mileage[['displacement','weight','acceleration']]
X
# Out:
#      displacement  weight  acceleration
# 0           307.0    3504          12.0
# 1           350.0    3693          11.5
# 2           318.0    3436          11.0
# 3           304.0    3433          12.0
# 4           302.0    3449          10.5
# ..            ...     ...           ...
# 393         140.0    2790          15.6
# 394          97.0    2130          24.6
# 395         135.0    2295          11.6
# 396         120.0    2625          18.6
# 397         119.0    2720          19.4
#
# [398 rows x 3 columns]

# %% [markdown]
# Train Test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.7, random_state=2529)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((278, 3), (120, 3), (278,), (120,))

# %% [markdown]
# Model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([15.75574953, 31.06844583, 18.4727436 , 23.49048512, 32.19676232,
#        30.1967664 , 24.7997337 , 12.74630672,  8.73781523, 29.087632  ,
#        30.70688667, 20.8301435 , 31.69579875, 14.43550914, 20.34935192,
#        14.95530585, 24.28742116, 31.74349346, 14.60825659, 11.88779705,
#        18.60446394, 30.52745118, 27.26826268, 18.43268596, 20.2345731 ,
#        25.77910407, 32.11852351, 30.40651227, 10.64978114, 25.74329675,
#         9.07960737, 26.805224  , 30.83900813, 20.40731714, 18.69857931,
#        20.19898308, 11.62766972, 23.90961134, 31.15304899, 33.2032139 ,
#        26.46247756, 31.32197765, 27.75623162, 18.87525198, 21.68263778,
#        24.57201813, 20.26484261, 29.67467877, 23.36326055, 24.83607076,
#        27.78583974, 12.36575975, 22.50340074, 32.43275594, 18.73236904,
#        14.08313194, 30.99412046, 26.79874713, 20.57431639, 29.65212505,
#        22.93331109, 31.22490136, 22.41626116,  8.60025108, 31.39376179,
# ...

# %%
from sklearn.metrics import mean_absolute_error, r2_score
mean_absolute_error(y_test,y_pred)
# Out:
# 3.5828286050868123

# %%
r2_score(y_test,y_pred)
# Out:
# 0.659732925310826
